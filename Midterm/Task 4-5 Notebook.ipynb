# %% [markdown]
# ## Task 4: Fine-Tuning Open-Source Embeddings

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
import langchain_community
langchain_community.__version__
# Out:
# '0.2.16'

# %%
# !pip install -qU langchain_openai langchain_huggingface langchain_core==0.2.38 langchain langchain_community langchain-text-splitters
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 834.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.2/290.2 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.4 MB/s eta 0:00:00

# %%
# !pip install -qU faiss-cpu unstructured==0.15.7 python-pptx==1.0.2 nltk==3.9.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 47.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.7 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done

# %%
# !pip install -qU qdrant-client pymupdf pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 383.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.9/258.9 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 18.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.28.2 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.2 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.2 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.2.3 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.2 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.2 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.2 which is incompatible.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key: ")
# Out:
# Enter Your OpenAI API Key: ··········

# %%
import langchain_core
import pandas as pd
langchain_core.__version__
# Out:
# '0.2.38'

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

pdf_links = [
    "https://www.whitehouse.gov/wp-content/uploads/2022/10/Blueprint-for-an-AI-Bill-of-Rights.pdf",
    "https://nvlpubs.nist.gov/nistpubs/ai/NIST.AI.600-1.pdf"
]

training_documents_loaded = []
for pdf_link in pdf_links:
    loader = PyMuPDFLoader(pdf_link)
    loaded_docs = loader.load()
    training_documents_loaded.extend(loaded_docs)

CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = CHUNK_SIZE,
    chunk_overlap = CHUNK_OVERLAP,
    length_function = len,
)
training_documents = text_splitter.split_documents(training_documents_loaded)

# %%
len(training_documents)
# Out:
# 512

# %%
import uuid

id_set = set()

for document in training_documents:
  id = str(uuid.uuid4())
  while id in id_set:
    id = uuid.uuid4()
  id_set.add(id)
  document.metadata["id"] = id

# %%
training_split_documents = training_documents[:380]
val_split_documents = training_documents[380:450]
test_split_documents = training_documents[450:512]

# %%
from langchain_openai import ChatOpenAI

qa_chat_model = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# %%
from langchain_core.prompts import ChatPromptTemplate

qa_prompt = """\
Given the following context, you must generate questions based on only the provided context.

You are to generate {n_questions} questions which should be provided in the following format:

1. QUESTION #1
2. QUESTION #2
...

Context:
{context}
"""

qa_prompt_template = ChatPromptTemplate.from_template(qa_prompt)

# %%
question_generation_chain = qa_prompt_template | qa_chat_model

# %%
import tqdm
def create_questions(documents, n_questions):
  questions = {}
  relevant_docs = {}
  for document in tqdm.tqdm(documents):
    #document_content = {"context" : document.page_content, "questions" : []}
    questions_generated = question_generation_chain.invoke({"context": document.page_content, "n_questions": n_questions})
    for question in questions_generated.content.split("\n"):
      question_id = str(uuid.uuid4())
      questions[question_id] = "".join(question.split(".")[1:]).strip()
      relevant_docs[question_id] = [document.metadata["id"]]
  return questions, relevant_docs

# %%
training_questions, training_relevant_contexts = create_questions(training_split_documents, 2)
# Out:
# 100%|██████████| 380/380 [09:22<00:00,  1.48s/it]

# %%
val_questions, val_relevant_contexts = create_questions(val_split_documents , 2)
# Out:
# 100%|██████████| 70/70 [01:35<00:00,  1.37s/it]

# %%
test_questions, test_relevant_contexts = create_questions(test_split_documents, 2)
# Out:
# 100%|██████████| 62/62 [01:47<00:00,  1.74s/it]

# %%
import json

training_corpus = {train_item.metadata["id"] : train_item.page_content for train_item in training_split_documents}

train_dataset = {
    "questions" : training_questions,
    "relevant_contexts" : training_relevant_contexts,
    "corpus" : training_corpus
}

with open("training_dataset.jsonl", "w") as f:
  json.dump(train_dataset, f)

# %%
val_corpus = {val_item.metadata["id"] : val_item.page_content for val_item in val_split_documents}

val_dataset = {
    "questions" : val_questions,
    "relevant_contexts" : val_relevant_contexts,
    "corpus" : val_corpus
}

with open("val_dataset.jsonl", "w") as f:
  json.dump(val_dataset, f)

# %%
train_corpus = {test_item.metadata["id"] : test_item.page_content for test_item in test_split_documents}

test_dataset = {
    "questions" : test_questions,
    "relevant_contexts" : test_relevant_contexts,
    "corpus" : train_corpus
}

with open("test_dataset.jsonl", "w") as f:
  json.dump(test_dataset, f)

# %%
import json
with open("training_dataset.jsonl", "r") as f:
    train_dataset = json.load(f)

with open("val_dataset.jsonl", "r") as f:
    val_dataset = json.load(f)

with open("test_dataset.jsonl", "r") as f:
    test_dataset = json.load(f)

# %%
test_dataset.keys()
# Out:
# dict_keys(['questions', 'relevant_contexts', 'corpus'])

# %%
import pyarrow
pyarrow.__version__
# Out:
# '14.0.2'

# %%
# !pip install -qU sentence_transformers datasets pyarrow==14.0.1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.28.2 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.3.1 which is incompatible.

# %%
from sentence_transformers import SentenceTransformer

model_id = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from sentence_transformers import InputExample

# %%
from datasets import Dataset

# %%
BATCH_SIZE = 30

# %% [markdown]
# Let's move our dataset into the expected format for training.

# %%
corpus = train_dataset['corpus']
queries = train_dataset['questions']
relevant_docs = train_dataset['relevant_contexts']

examples = []
for query_id, query in queries.items():
    doc_id = relevant_docs[query_id][0]
    text = corpus[doc_id]
    example = InputExample(texts=[query, text])
    examples.append(example)

# %%
loader = DataLoader(
    examples, batch_size=BATCH_SIZE
)

# %%
from sentence_transformers.losses import MatryoshkaLoss, MultipleNegativesRankingLoss

matryoshka_dimensions = [384,128]
inner_train_loss = MultipleNegativesRankingLoss(model)
train_loss = MatryoshkaLoss(
    model, inner_train_loss, matryoshka_dims=matryoshka_dimensions
)

# %%
from sentence_transformers.evaluation import InformationRetrievalEvaluator

corpus = val_dataset['corpus']
queries = val_dataset['questions']
relevant_docs = val_dataset['relevant_contexts']

evaluator = InformationRetrievalEvaluator(queries, corpus, relevant_docs)

# %%
EPOCHS = 5

# %%
warmup_steps = int(len(loader) * EPOCHS * 0.1)

model.fit(
    train_objectives=[(loader, train_loss)],
    epochs=EPOCHS,
    warmup_steps=warmup_steps,
    output_path='finetuned_MiniLM',
    show_progress_bar=True,
    evaluator=evaluator,
    evaluation_steps=50,
)
# Out:
#     <div>
#
#       <progress value='130' max='130' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [130/130 00:35, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cosine Accuracy@1</th>
#       <th>Cosine Accuracy@3</th>
#       <th>Cosine Accuracy@5</th>
#       <th>Cosine Accuracy@10</th>
#       <th>Cosine Precision@1</th>
#       <th>Cosine Precision@3</th>
#       <th>Cosine Precision@5</th>
#       <th>Cosine Precision@10</th>
#       <th>Cosine Recall@1</th>
#       <th>Cosine Recall@3</th>
#       <th>Cosine Recall@5</th>
#       <th>Cosine Recall@10</th>
#       <th>Cosine Ndcg@10</th>
#       <th>Cosine Mrr@10</th>
#       <th>Cosine Map@100</th>
#       <th>Dot Accuracy@1</th>
#       <th>Dot Accuracy@3</th>
#       <th>Dot Accuracy@5</th>
#       <th>Dot Accuracy@10</th>
#       <th>Dot Precision@1</th>
#       <th>Dot Precision@3</th>
#       <th>Dot Precision@5</th>
#       <th>Dot Precision@10</th>
#       <th>Dot Recall@1</th>
#       <th>Dot Recall@3</th>
#       <th>Dot Recall@5</th>
#       <th>Dot Recall@10</th>
#       <th>Dot Ndcg@10</th>
#       <th>Dot Mrr@10</th>
#       <th>Dot Map@100</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>26</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.650000</td>
#       <td>0.828571</td>
#       <td>0.892857</td>
#       <td>0.971429</td>
#       <td>0.650000</td>
#       <td>0.276190</td>
#       <td>0.178571</td>
#       <td>0.097143</td>
#       <td>0.650000</td>
#       <td>0.828571</td>
#       <td>0.892857</td>
#       <td>0.971429</td>
#       <td>0.810544</td>
#       <td>0.759184</td>
#       <td>0.760995</td>
#       <td>0.650000</td>
#       <td>0.828571</td>
#       <td>0.892857</td>
#       <td>0.971429</td>
#       <td>0.650000</td>
#       <td>0.276190</td>
#       <td>0.178571</td>
#       <td>0.097143</td>
#       <td>0.650000</td>
#       <td>0.828571</td>
#       <td>0.892857</td>
#       <td>0.971429</td>
#       <td>0.810544</td>
#       <td>0.759184</td>
#       <td>0.760995</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.714286</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.841933</td>
#       <td>0.801905</td>
#       <td>0.804701</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.714286</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.841933</td>
#       <td>0.801905</td>
#       <td>0.804701</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.714286</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.842246</td>
#       <td>0.802262</td>
#       <td>0.805058</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.714286</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.714286</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.842246</td>
#       <td>0.802262</td>
#       <td>0.805058</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.847379</td>
#       <td>0.808929</td>
#       <td>0.811572</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.096429</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.964286</td>
#       <td>0.847379</td>
#       <td>0.808929</td>
#       <td>0.811572</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.851464</td>
#       <td>0.812211</td>
#       <td>0.814229</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.851464</td>
#       <td>0.812211</td>
#       <td>0.814229</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.851464</td>
#       <td>0.812211</td>
#       <td>0.814229</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.721429</td>
#       <td>0.292857</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.721429</td>
#       <td>0.878571</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.851464</td>
#       <td>0.812211</td>
#       <td>0.814229</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.714286</td>
#       <td>0.885714</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.714286</td>
#       <td>0.295238</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.714286</td>
#       <td>0.885714</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.848473</td>
#       <td>0.808124</td>
#       <td>0.810142</td>
#       <td>0.714286</td>
#       <td>0.885714</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.714286</td>
#       <td>0.295238</td>
#       <td>0.190000</td>
#       <td>0.097143</td>
#       <td>0.714286</td>
#       <td>0.885714</td>
#       <td>0.950000</td>
#       <td>0.971429</td>
#       <td>0.848473</td>
#       <td>0.808124</td>
#       <td>0.810142</td>
#     </tr>
#   </tbody>
# </table><p>
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
ftmodel = SentenceTransformer("finetuned_MiniLM")
ftmodel.push_to_hub("yinong333/finetuned_MiniLM")
# Out:
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# 'https://huggingface.co/yinong333/finetuned_MiniLM/commit/000786badfaa76d44c2092f2d0cba1067f66d47c'

# %% [markdown]
# ## Task 5: Assessing Performance
#
# Check 1: is_hit rate

# %%
import pandas as pd

from langchain_community.vectorstores import FAISS
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
def evaluate_openai(
    dataset,
    embed_model,
    top_k=5,
    verbose=False,
):
  corpus = dataset['corpus']
  questions = dataset['questions']
  relevant_docs = dataset['relevant_contexts']
  documents = [Document(page_content=content, metadata={"id": doc_id}) for doc_id, content in corpus.items()]
  vectorstore = FAISS.from_documents(documents, embed_model)

  retriever = vectorstore.as_retriever(search_kwargs={"k": top_k})

  eval_results = []
  for id, question in tqdm.tqdm(questions.items()):
    retrieved_nodes = retriever.invoke(question)
    retrieved_ids = [node.metadata["id"] for node in retrieved_nodes]
    expected_id = relevant_docs[id][0]
    is_hit = expected_id in retrieved_ids
    eval_results.append({"id": id, "question": question, "expected_id": expected_id, "is_hit": is_hit})

  return eval_results

# %% [markdown]
# ### `text-embedding-3-small`

# %%
te3_openai = OpenAIEmbeddings(model="text-embedding-3-small")
te3_results = evaluate_openai(test_dataset, te3_openai)
# Out:
# 100%|██████████| 124/124 [00:51<00:00,  2.42it/s]

# %%
te3_results_df = pd.DataFrame(te3_results)

# %%
te3_hit_rate = te3_results_df["is_hit"].mean()
te3_hit_rate
# Out:
# 0.9516129032258065

# %% [markdown]
# ### `sentence-transformers/all-MiniLM-L6-v2` (base)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
from langchain_huggingface import HuggingFaceEmbeddings

huggingface_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
MiniLM_results = evaluate_openai(test_dataset, huggingface_embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 124/124 [00:00<00:00, 131.42it/s]

# %%
MiniLM_results_df = pd.DataFrame(MiniLM_results)

# %%
MiniLM_results_df = MiniLM_results_df["is_hit"].mean()
MiniLM_results_df
# Out:
# 0.8709677419354839

# %% [markdown]
# ### `sentence-transformers/all-MiniLM-L6-v2` (fine-tuned)

# %%
finetune_embeddings = HuggingFaceEmbeddings(model_name="finetuned_MiniLM")
finetune_results = evaluate_openai(test_dataset, finetune_embeddings)
# Out:
# 100%|██████████| 124/124 [00:00<00:00, 134.72it/s]

# %%
finetune_results_df = pd.DataFrame(finetune_results)

# %%
finetune_hit_rate = finetune_results_df["is_hit"].mean()
finetune_hit_rate
# Out:
# 0.9596774193548387

# %% [markdown]
# Check 2: RAGAS
#
# Step 1: create base rag chain

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 750,
    chunk_overlap  = 50,
    length_function = len
)

training_documents = text_splitter.split_documents(training_documents_loaded)

# %%
from langchain_community.vectorstores import FAISS

base_vectorstore = FAISS.from_documents(training_documents, huggingface_embeddings)
base_retriever = base_vectorstore.as_retriever(search_kwargs={"k": 6})

from langchain_core.prompts import ChatPromptTemplate

RAG_PROMPT = """\
Given a provided context and a question, you must answer the question. If you do not know the answer, you must state that you do not know.

Context:
{context}

Question:
{question}

Answer:
"""

rag_prompt_template = ChatPromptTemplate.from_template(RAG_PROMPT)
rag_llm =  ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableParallel

base_rag_chain = (
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %%
base_rag_chain.invoke({"question" : "How can adversarial role-playing exercises help identify anomalous failure modes related to information integrity in GAI systems?"})["response"]
# Out:
# "Adversarial role-playing exercises can help identify anomalous failure modes related to information integrity in Generative Artificial Intelligence (GAI) systems by simulating potential attack scenarios and testing the system's responses under various conditions. These exercises allow participants to take on the roles of both the operators and adversaries, which can reveal vulnerabilities and weaknesses in the system that may not be apparent during standard testing. By challenging the GAI system in a controlled environment, it becomes possible to uncover unforeseen failure modes, assess the robustness of the information integrity measures in place, and develop strategies to mitigate risks associated with those vulnerabilities. This proactive approach enhances the overall security and reliability of GAI systems."

# %% [markdown]
# Step 2: create fine-tuned rag chain

# %%
finetune_vectorstore = FAISS.from_documents(training_documents, finetune_embeddings)
finetune_retriever = finetune_vectorstore.as_retriever(search_kwargs={"k": 6})

# %%
finetune_rag_chain = (
    {"context": itemgetter("question") | finetune_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %%
finetune_rag_chain.invoke({"question" : "How can adversarial role-playing exercises help identify anomalous failure modes related to information integrity in GAI systems?"})["response"]
# Out:
# "Adversarial role-playing exercises can help identify anomalous failure modes related to information integrity in Generative Artificial Intelligence (GAI) systems by simulating scenarios where the system may be manipulated or misused. These exercises allow participants to take on different roles, including that of an adversary, to challenge the GAI system's responses and behaviors. By doing so, they can uncover vulnerabilities in the system's design, data handling, and output generation processes.\n\nThrough these exercises, participants can test the system's ability to maintain information integrity under various conditions, such as when faced with misleading inputs or attempts to generate deceptive outputs. This can reveal weaknesses in the system's content verification processes, data provenance tracking, and overall reliability. Additionally, the insights gained from these exercises can inform the development of more robust safeguards and protocols to enhance the system's resilience against potential threats to information integrity."

# %%
t3_vectorstore = FAISS.from_documents(training_documents, te3_openai)
t3_retriever = t3_vectorstore.as_retriever(search_kwargs={"k": 6})
t3_rag_chain = (
    {"context": itemgetter("question") | t3_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# Step 3: create RAGAS synthetic data

# %%
# !pip install -qU langchain_openai langchain_huggingface langchain_core==0.2.38

# %%
# !pip install -qU ragas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 5.4 MB/s eta 0:00:00

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import OpenAIEmbeddings

generator_llm = ChatOpenAI(model="gpt-3.5-turbo")
critic_llm = ChatOpenAI(model="gpt-4o-mini")
embeddings = OpenAIEmbeddings()

# %%
generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

# %%
testset_df = pd.read_csv("testset.csv", index_col=0)

# %%
testset_df.head()
# Out:
#                                             question  \
# 0  How can adversarial role-playing exercises hel...
# 1  Who is Karen Levy and what is her role in disc...
# 2  How should organizations establish minimum thr...
# 3  What is the significance of algorithmic discri...
# 4  How can risks be re-evaluated when adapting GA...
#
#                                             contexts  \
# 0  ['Violent, or Hateful Content; \nObscene, Degr...
# 1  ['•\nKaren Levy, Assistant Professor, Departme...
# 2  ['Dangerous, Violent, or Hateful \nContent; CB...
# 3  ['healthcare clinical algorithms that are used...
# 4  ['models. \nValue Chain and Component \nIntegr...
#
#                                         ground_truth evolution_type  \
# 0  Adversarial role-playing exercises can help id...         simple
# 1  Karen Levy is an Assistant Professor in the De...         simple
# 2  Organizations should establish minimum thresho...         simple
# 3  Algorithmic discrimination protections in heal...         simple
# 4  Risks can be re-evaluated when adapting GAI mo...         simple
#
#                                             metadata  episode_done
# 0  [{'source': 'https://nvlpubs.nist.gov/nistpubs...          True
# 1  [{'source': 'https://www.whitehouse.gov/wp-con...          True
# 2  [{'source': 'https://nvlpubs.nist.gov/nistpubs...          True
# 3  [{'source': 'https://www.whitehouse.gov/wp-con...          True
# 4  [{'source': 'https://nvlpubs.nist.gov/nistpubs...          True

# %%
from datasets import Dataset

def generate_answers(chain, testset_df):
  answers = []
  contexts = []
  questions = testset_df["question"].values.tolist()
  ground_truths = testset_df["ground_truth"].values.tolist()

  for question in tqdm.tqdm(questions):
    answer = chain.invoke({"question" : question})
    answers.append(answer["response"])
    contexts.append([context.page_content for context in answer["context"]])

  return Dataset.from_dict({
      "question" : questions,
      "answer" : answers,
      "contexts" : contexts,
      "ground_truth" : ground_truths
  })

# %%
base_dataset = generate_answers(base_rag_chain, testset_df)
# Out:
# 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]

# %%
finetune_dataset = generate_answers(finetune_rag_chain, testset_df)
# Out:
# 100%|██████████| 20/20 [00:39<00:00,  1.98s/it]

# %%
t3_dataset = generate_answers(t3_rag_chain, testset_df)
# Out:
# 100%|██████████| 20/20 [01:04<00:00,  3.23s/it]

# %% [markdown]
# Step 4: evaluate base rag chain VS fine tune rag chain

# %%
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
from ragas import evaluate

result = evaluate(
    base_dataset,
    metrics)
print("base_rag_chain: ", result)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# base_rag_chain:  {'faithfulness': 0.8380, 'answer_relevancy': 0.9672, 'context_recall': 0.8958, 'context_precision': 0.8820, 'answer_correctness': 0.7260}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [vulnerabilities and potential manipulation or...
# 1   [•\nNatasha Duarte, Project Director, Upturn\n...
# 2   [Human-AI Conﬁguration; Obscene, \nDegrading, ...
# 3   [steps taken to mitigate potential harms, shou...
# 4   [GAI resources; Apply organizational risk tole...
# 5   [privileges after gaining system access. \nInf...
# 6   [systems and some other digital technologies, ...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [organizations to mitigate risks to the safety...
# 9   [when implementing feedback activities. \nAI R...
# 10  [together information from disparate sources. ...
# 11  [WHAT SHOULD BE EXPECTED OF AUTOMATED SYSTEMS\...
# 12  [varying contexts where GAI will be used. For ...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [national security needs, individuals subject ...
# 15  [and the Rights of Citizens.4 While there is n...
# 16  [­­­­­­­\nALGORITHMIC DISCRIMINATION Protectio...
# 17  [the Privacy Act, federal agencies may only re...
# 18  [29 \nMS-1.1-006 \nImplement continuous monito...
# 19  [content detection mechanisms provide informat...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1   Karen Levy is an Assistant Professor in the De...
# 2   Organizations should establish minimum thresho...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting GAI mo...
# 5   Information security for GAI models and system...
# 6   Label errors can impact the stability and robu...
# 7   Transparency is important in predictive polici...
# 8   Some innovative solutions provided by industry...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly affect perce...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  Safeguards needed to protect individuals from ...
# 15  The technical guide in the AI Bill of Rights a...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act allows individuals to access t...
# 18  GAI red-teaming can assess data quality for AI...
# 19  Integrating tools for content provenance analy...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      0.153846
# 1   Karen Levy is an Assistant Professor in the De...      1.000000
# 2   Organizations should establish minimum thresho...      0.428571
# 3   Algorithmic discrimination protections in heal...      0.642857
# 4   Risks can be re-evaluated when adapting GAI mo...      1.000000
# 5   Information security for GAI models and system...      1.000000
# 6   Label errors in test datasets used to benchmar...      1.000000
# 7   Transparency is important in predictive polici...      0.888889
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      1.000000
# 10  GAI alterations can significantly impact perce...      1.000000
# 11  Designers, developers, and deployers of automa...      0.777778
# 12  AI red teams should consider domain expertise,...      1.000000
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      1.000000
# 15  The answer to given question is not present in...      0.818182
# 16  Proactive testing should be performed to ident...      1.000000
# 17  The Privacy Act allows individuals to access t...      1.000000
# 18  GAI red-teaming can assess data quality for AI...      0.750000
# 19  Integrating tools for content provenance analy...      0.300000
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.938997        1.000000           1.000000            0.621549
# 1           0.890264        1.000000           0.200000            0.910128
# 2           0.877588        0.500000           0.950000            0.895691
# 3           1.000000        1.000000           1.000000            0.617326
# 4           1.000000        0.666667           1.000000            0.584088
# 5           0.997251        1.000000           1.000000            0.946907
# 6           0.943874        1.000000           1.000000            0.992536
# 7           1.000000        1.000000           0.926667            0.792944
# 8           0.973194        1.000000           1.000000            0.547081
# 9           0.999989        0.333333           0.876667            0.625688
# 10          0.953586        1.000000           1.000000            0.533828
# 11          0.974921        0.750000           1.000000            0.634215
# 12          0.960951        1.000000           1.000000            0.657897
# 13          0.983238        1.000000           0.866667            0.994318
# 14          1.000000        1.000000           1.000000            0.993432
# 15          0.974910        1.000000           0.000000            0.175698
# 16          1.000000        1.000000           1.000000            0.467328
# 17          0.915098        1.000000           1.000000            0.708743
# 18          1.000000        1.000000           0.854167            0.995449
# 19          0.959486        0.666667           0.966667            0.825915

# %%
result = evaluate(
    finetune_dataset,
    metrics)
print("fine_tune_rag_chain: ", result)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# fine_tune_rag_chain:  {'faithfulness': 0.8417, 'answer_relevancy': 0.9644, 'context_recall': 0.9083, 'context_precision': 0.8878, 'answer_correctness': 0.7437}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [vulnerabilities and potential manipulation or...
# 1   [•\nNatasha Duarte, Project Director, Upturn\n...
# 2   [Human-AI Conﬁguration; Obscene, \nDegrading, ...
# 3   [sociodemographic variables that adjust or “co...
# 4   [GAI resources; Apply organizational risk tole...
# 5   [privileges after gaining system access. \nInf...
# 6   [Inaccuracies in these labels can impact the “...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [organizations to mitigate risks to the safety...
# 9   [transformers, etc.); Optimization objectives;...
# 10  [10 \nGAI systems can ease the unintentional p...
# 11  [WHAT SHOULD BE EXPECTED OF AUTOMATED SYSTEMS\...
# 12  [varying contexts where GAI will be used. For ...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [national security needs, individuals subject ...
# 15  [and the Rights of Citizens.4 While there is n...
# 16  [steps taken to mitigate potential harms, shou...
# 17  [the Privacy Act, federal agencies may only re...
# 18  [29 \nMS-1.1-006 \nImplement continuous monito...
# 19  [content detection mechanisms provide informat...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1   Karen Levy is an Assistant Professor in the De...
# 2   Organizations should establish minimum thresho...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting GAI mo...
# 5   Information security for GAI models and system...
# 6   Label errors can impact the stability and robu...
# 7   Transparency is important in predictive polici...
# 8   Some innovative solutions provided by industry...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly affect perce...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  Safeguards needed to protect individuals from ...
# 15  The technical guide protects data privacy in t...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act allows individuals to access t...
# 18  GAI red-teaming can assess data quality for AI...
# 19  Integrating tools for content provenance analy...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      0.700000
# 1   Karen Levy is an Assistant Professor in the De...      1.000000
# 2   Organizations should establish minimum thresho...      0.500000
# 3   Algorithmic discrimination protections in heal...      0.700000
# 4   Risks can be re-evaluated when adapting GAI mo...      0.900000
# 5   Information security for GAI models and system...      1.000000
# 6   Label errors in test datasets used to benchmar...      1.000000
# 7   Transparency is important in predictive polici...      0.777778
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      0.333333
# 10  GAI alterations can significantly impact perce...      1.000000
# 11  Designers, developers, and deployers of automa...      0.913043
# 12  AI red teams should consider domain expertise,...      1.000000
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      1.000000
# 15  The answer to given question is not present in...      0.857143
# 16  Proactive testing should be performed to ident...      1.000000
# 17  The Privacy Act allows individuals to access t...      0.875000
# 18  GAI red-teaming can assess data quality for AI...      0.777778
# 19  Integrating tools for content provenance analy...      0.500000
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.938997        0.666667           0.887500            0.863606
# 1           0.890264        1.000000           0.333333            0.820385
# 2           0.877588        0.500000           0.887500            0.990011
# 3           1.000000        1.000000           1.000000            0.918007
# 4           0.962327        1.000000           1.000000            0.523702
# 5           0.997251        1.000000           1.000000            0.696217
# 6           0.943874        1.000000           1.000000            0.917603
# 7           1.000000        0.666667           0.876667            0.810313
# 8           0.973194        1.000000           1.000000            0.547081
# 9           0.999992        0.333333           0.854167            0.594229
# 10          0.921203        1.000000           1.000000            0.525775
# 11          0.998483        1.000000           1.000000            0.784318
# 12          0.960951        1.000000           1.000000            0.599250
# 13          1.000000        1.000000           1.000000            0.780171
# 14          1.000000        1.000000           1.000000            0.993207
# 15          1.000000        1.000000           0.000000            0.926186
# 16          0.981436        1.000000           1.000000            0.346097
# 17          0.901488        1.000000           1.000000            0.746226
# 18          1.000000        1.000000           0.916667            0.745860
# 19          0.941742        1.000000           1.000000            0.746649

# %%
from ragas import evaluate
result = evaluate(
    t3_dataset,
    metrics)
print("t3_rag_chain: ", result)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# t3_rag_chain:  {'faithfulness': 0.8784, 'answer_relevancy': 0.9193, 'context_recall': 0.9083, 'context_precision': 0.8557, 'answer_correctness': 0.7048}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [including tests to address attempts to deceiv...
# 1   [•\nNatasha Duarte, Project Director, Upturn\n...
# 2   [Human-AI Conﬁguration; Obscene, \nDegrading, ...
# 3   [­­­­­­­\nALGORITHMIC DISCRIMINATION Protectio...
# 4   [GAI resources; Apply organizational risk tole...
# 5   [privileges after gaining system access. \nInf...
# 6   [systems and some other digital technologies, ...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [organizations to mitigate risks to the safety...
# 9   [when implementing feedback activities. \nAI R...
# 10  [make it possible to generate both text-based ...
# 11  [system should ensure that documentation descr...
# 12  [varying contexts where GAI will be used. For ...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [national security needs, individuals subject ...
# 15  [Legal Disclaimer \nThe Blueprint for an AI Bi...
# 16  [and deployers of automated systems should tak...
# 17  [Further, the Privacy Act allows for a cause o...
# 18  [when implementing feedback activities. \nAI R...
# 19  [content detection mechanisms provide informat...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1   Karen Levy is an Assistant Professor in the De...
# 2   Organizations should establish minimum thresho...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting GAI mo...
# 5   Information security for Generative Artificial...
# 6   Label errors can impact the stability and robu...
# 7   Transparency is important in predictive polici...
# 8   Some innovative solutions provided by industry...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly manipulate h...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  To protect individuals from government surveil...
# 15  The technical guide in the AI Bill of Rights a...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act allows individuals to seek leg...
# 18  The provided context does not specifically men...
# 19  Integrating tools for content provenance analy...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      0.600000
# 1   Karen Levy is an Assistant Professor in the De...      1.000000
# 2   Organizations should establish minimum thresho...      0.833333
# 3   Algorithmic discrimination protections in heal...      0.416667
# 4   Risks can be re-evaluated when adapting GAI mo...      1.000000
# 5   Information security for GAI models and system...      0.846154
# 6   Label errors in test datasets used to benchmar...      1.000000
# 7   Transparency is important in predictive polici...      0.777778
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      0.500000
# 10  GAI alterations can significantly impact perce...      0.944444
# 11  Designers, developers, and deployers of automa...      0.913043
# 12  AI red teams should consider domain expertise,...      1.000000
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      0.952381
# 15  The answer to given question is not present in...      0.909091
# 16  Proactive testing should be performed to ident...      1.000000
# 17  The Privacy Act allows individuals to access t...      1.000000
# 18  GAI red-teaming can assess data quality for AI...      1.000000
# 19  Integrating tools for content provenance analy...      0.875000
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.938997        1.000000           0.691667            0.798229
# 1           0.956980        1.000000           0.333333            0.997273
# 2           0.899640        1.000000           0.926667            0.327958
# 3           1.000000        1.000000           1.000000            0.718381
# 4           1.000000        0.666667           1.000000            0.557889
# 5           0.942244        1.000000           1.000000            0.942583
# 6           0.943874        1.000000           0.887500            0.991214
# 7           1.000000        0.666667           1.000000            0.890067
# 8           0.973194        1.000000           0.691667            0.621827
# 9           1.000000        0.666667           0.950000            0.663565
# 10          0.955660        1.000000           1.000000            0.898817
# 11          0.998483        1.000000           1.000000            0.986496
# 12          0.960951        1.000000           1.000000            0.813260
# 13          1.000000        1.000000           1.000000            0.936574
# 14          1.000000        1.000000           1.000000            0.992612
# 15          0.960540        1.000000           0.000000            0.176397
# 16          1.000000        1.000000           1.000000            0.420790
# 17          0.895943        1.000000           1.000000            0.744253
# 18          0.000000        0.500000           0.666667            0.220609
# 19          0.959486        0.666667           0.966667            0.396356

# %% [markdown]
# Step 5: evaluate chunk size 500 chain VS chunk size 1000

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap  = 50,
    length_function = len
)

training_documents = text_splitter.split_documents(training_documents_loaded)

chunk_500_vectorstore = FAISS.from_documents(training_documents, huggingface_embeddings)
chunk_500_retriever = chunk_500_vectorstore.as_retriever(search_kwargs={"k": 4})

chunk_500_rag_chain = (
    {"context": itemgetter("question") | chunk_500_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)
chunk_500_dataset = generate_answers(chunk_500_rag_chain, testset_df)
result = evaluate(
    chunk_500_dataset,
    metrics)
print("chunk_500_results: ", result)
# Out:
# 100%|██████████| 20/20 [00:33<00:00,  1.67s/it]
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# chunk_500_results:  {'faithfulness': 0.7550, 'answer_relevancy': 0.8304, 'context_recall': 0.7833, 'context_precision': 0.8389, 'answer_correctness': 0.6728}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [estimates. \nInformation Integrity; CBRN \nIn...
# 1   [•\nFabian Rogers, Constituent Advocate, Offic...
# 2   [Violent, or Hateful Content; \nObscene, Degra...
# 3   [­­­­­­­\nALGORITHMIC DISCRIMINATION Protectio...
# 4   [and Component Integration \nMP-4.1-007 Re-eva...
# 5   [actors might further these risks by developin...
# 6   [these sources. \nErrors in third-party GAI co...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [innovate.15 At the same time, rules of the ro...
# 9   [expected to use the model or interact with it...
# 10  [10 \nGAI systems can ease the unintentional p...
# 11  [WHAT SHOULD BE EXPECTED OF AUTOMATED SYSTEMS\...
# 12  [red-teaming can be performed before or after ...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [rights must not be limited by the threat of s...
# 15  [provides examples and concrete steps for comm...
# 16  [systems have the capacity to drive extraordin...
# 17  [system of records, and must provide procedure...
# 18  [red-teaming can be performed before or after ...
# 19  [videos, audio, and underlying datasets. The i...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1                                      I do not know.
# 2   The provided context does not specify how orga...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting GAI mo...
# 5   Information security for GAI models and system...
# 6   Label errors can impact the stability and robu...
# 7   Transparency is important in predictive polici...
# 8   The context mentions that industry is providin...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly affect perce...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  Safeguards needed to protect individuals from ...
# 15  The technical guide in the AI Bill of Rights a...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act helps individuals correct pers...
# 18  GAI red-teaming can assess data quality for AI...
# 19  Integrating tools designed for content provena...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      0.428571
# 1   Karen Levy is an Assistant Professor in the De...      0.000000
# 2   Organizations should establish minimum thresho...      0.666667
# 3   Algorithmic discrimination protections in heal...      0.181818
# 4   Risks can be re-evaluated when adapting GAI mo...      1.000000
# 5   Information security for GAI models and system...      1.000000
# 6   Label errors in test datasets used to benchmar...      1.000000
# 7   Transparency is important in predictive polici...      1.000000
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      0.333333
# 10  GAI alterations can significantly impact perce...      0.933333
# 11  Designers, developers, and deployers of automa...      1.000000
# 12  AI red teams should consider domain expertise,...      1.000000
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      1.000000
# 15  The answer to given question is not present in...      0.555556
# 16  Proactive testing should be performed to ident...      0.230769
# 17  The Privacy Act allows individuals to access t...      1.000000
# 18  GAI red-teaming can assess data quality for AI...      1.000000
# 19  Integrating tools for content provenance analy...      0.769231
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.940960        1.000000           1.000000            0.798589
# 1           0.000000        0.500000           0.000000            0.186041
# 2           0.000000        0.500000           0.805556            0.407823
# 3           1.000000        1.000000           1.000000            0.825849
# 4           1.000000        1.000000           1.000000            0.887030
# 5           0.997251        0.500000           1.000000            0.741724
# 6           0.942043        0.500000           1.000000            0.991905
# 7           1.000000        0.666667           1.000000            0.818489
# 8           0.000000        1.000000           0.750000            0.505157
# 9           1.000000        0.333333           0.416667            0.644275
# 10          0.939283        0.666667           1.000000            0.860696
# 11          0.998483        0.500000           0.805556            0.799692
# 12          0.960951        1.000000           1.000000            0.527353
# 13          0.983238        1.000000           1.000000            0.618696
# 14          1.000000        1.000000           1.000000            0.992895
# 15          0.974910        1.000000           0.000000            0.177262
# 16          1.000000        1.000000           1.000000            0.820871
# 17          0.942457        1.000000           1.000000            0.780848
# 18          1.000000        0.500000           1.000000            0.562372
# 19          0.928164        1.000000           1.000000            0.508562

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap  = 200,
    length_function = len
)

training_documents = text_splitter.split_documents(training_documents_loaded)

chunk_1000_vectorstore = FAISS.from_documents(training_documents, huggingface_embeddings)
chunk_1000_retriever = chunk_1000_vectorstore.as_retriever(search_kwargs={"k": 4})

chunk_1000_rag_chain = (
    {"context": itemgetter("question") | chunk_1000_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)
chunk_1000_dataset = generate_answers(chunk_1000_rag_chain, testset_df)
result = evaluate(
    chunk_1000_dataset,
    metrics
)
print("chunk_1000_results: ", result)
# Out:
# 100%|██████████| 20/20 [00:34<00:00,  1.70s/it]
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# chunk_1000_results:  {'faithfulness': 0.8457, 'answer_relevancy': 0.9276, 'context_recall': 0.9000, 'context_precision': 0.8861, 'answer_correctness': 0.7830}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [disclosures. \nHuman-AI Conﬁguration \nMP-5.1...
# 1   [•\nElana Zeide, Assistant Professor, Universi...
# 2   [using: ﬁeld testing with sub-group population...
# 3   [­­­­­­­\nALGORITHMIC DISCRIMINATION Protectio...
# 4   [case context. \nOrganizations may choose to t...
# 5   [vulnerabilities in systems (hardware, softwar...
# 6   [training data, which may be too large for hum...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [The National Highway Traffic Safety Administr...
# 9   [preferences and experiences towards AI risks ...
# 10  [10 \nGAI systems can ease the unintentional p...
# 11  [NOTICE & \nEXPLANATION \nWHAT SHOULD BE EXPEC...
# 12  [behavior or outcomes of a GAI model or system...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [specific real-world context. Such assessment ...
# 15  [and the Rights of Citizens.4 While there is n...
# 16  [­­­­­­­\nALGORITHMIC DISCRIMINATION Protectio...
# 17  [accomplish an agency’s statutory purpose or t...
# 18  [training data, which may be too large for hum...
# 19  [date/time of creation, location, modiﬁcations...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1                                      I do not know.
# 2   Organizations should establish minimum thresho...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting GAI mo...
# 5   Information security for GAI models and system...
# 6   Label errors can impact the stability and robu...
# 7   Transparency is important in predictive polici...
# 8   Some innovative solutions provided by industry...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly affect perce...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  Safeguards needed to protect individuals from ...
# 15  The technical guide in the AI Bill of Rights a...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act helps individuals correct pers...
# 18  GAI red-teaming can assess data quality for AI...
# 19  Integrating tools for content provenance analy...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      0.800000
# 1   Karen Levy is an Assistant Professor in the De...      0.000000
# 2   Organizations should establish minimum thresho...      0.916667
# 3   Algorithmic discrimination protections in heal...      1.000000
# 4   Risks can be re-evaluated when adapting GAI mo...      1.000000
# 5   Information security for GAI models and system...      0.727273
# 6   Label errors in test datasets used to benchmar...      1.000000
# 7   Transparency is important in predictive polici...      1.000000
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      1.000000
# 10  GAI alterations can significantly impact perce...      0.600000
# 11  Designers, developers, and deployers of automa...      1.000000
# 12  AI red teams should consider domain expertise,...      0.857143
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      1.000000
# 15  The answer to given question is not present in...      0.750000
# 16  Proactive testing should be performed to ident...      0.875000
# 17  The Privacy Act allows individuals to access t...      1.000000
# 18  GAI red-teaming can assess data quality for AI...      1.000000
# 19  Integrating tools for content provenance analy...      0.388889
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.938997        1.000000           1.000000            0.846059
# 1           0.000000        0.500000           0.000000            0.186041
# 2           0.933373        1.000000           1.000000            0.325192
# 3           1.000000        1.000000           1.000000            0.893624
# 4           0.982718        0.500000           1.000000            0.819366
# 5           0.997251        1.000000           1.000000            0.857553
# 6           0.943874        1.000000           0.916667            0.991822
# 7           1.000000        0.666667           0.805556            0.997066
# 8           0.965506        1.000000           1.000000            0.998831
# 9           1.000000        1.000000           1.000000            0.990256
# 10          0.966678        0.666667           1.000000            0.840627
# 11          0.998483        1.000000           1.000000            0.797108
# 12          0.960951        1.000000           1.000000            0.938233
# 13          1.000000        1.000000           1.000000            0.769950
# 14          1.000000        1.000000           1.000000            0.724994
# 15          0.981202        1.000000           0.000000            0.927649
# 16          0.980625        1.000000           1.000000            0.830363
# 17          0.942457        1.000000           1.000000            0.995932
# 18          1.000000        1.000000           1.000000            0.547135
# 19          0.959486        0.666667           1.000000            0.383056

# %%
text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n"], # Prioritize paragraph breaks, then line breaks
        chunk_size=10000,
        chunk_overlap=50
        )

training_documents = text_splitter.split_documents(training_documents_loaded)

chunk_section_vectorstore = FAISS.from_documents(training_documents, huggingface_embeddings)
chunk_section_retriever = chunk_section_vectorstore.as_retriever(search_kwargs={"k": 4})

chunk_section_rag_chain = (
    {"context": itemgetter("question") | chunk_section_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)
chunk_section_dataset = generate_answers(chunk_section_rag_chain, testset_df)
result = evaluate(
    chunk_section_dataset,
    metrics
)
print("chunk_section_results: ", result)
# Out:
# 100%|██████████| 20/20 [00:55<00:00,  2.79s/it]
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# chunk_section_results:  {'faithfulness': 0.8802, 'answer_relevancy': 0.9652, 'context_recall': 0.9667, 'context_precision': 0.9375, 'answer_correctness': 0.7438}

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   How can adversarial role-playing exercises hel...
# 1   Who is Karen Levy and what is her role in disc...
# 2   How should organizations establish minimum thr...
# 3   What is the significance of algorithmic discri...
# 4   How can risks be re-evaluated when adapting GA...
# 5   How can information security be maintained for...
# 6   How can label errors impact the stability and ...
# 7   Why is transparency important in predictive po...
# 8   What are some innovative solutions provided by...
# 9   What are the risks associated with model extra...
# 10  How do GAI alterations affect perception, cons...
# 11  How can transparency and accessibility be ensu...
# 12  What factors should AI red teams consider when...
# 13  How can GAI systems be used to create targeted...
# 14  What safeguards are needed to protect individu...
# 15  How does the technical guide protect data priv...
# 16  How can organizations prevent algorithmic disc...
# 17  How does the Privacy Act help individuals corr...
# 18  How can GAI red-teaming assess data quality fo...
# 19  What can be achieved by integrating tools for ...
#
#                                              contexts  \
# 0   [25 \nMP-2.3-002 Review and document accuracy,...
# 1   [APPENDIX\nPanel 3: Equal Opportunities and Ci...
# 2   [32 \nMEASURE 2.6: The AI system is evaluated ...
# 3   [Algorithmic \nDiscrimination \nProtections \n...
# 4   [3 \nthe abuse, misuse, and unsafe repurposing...
# 5   [17 \nGOVERN 1.7: Processes and procedures are...
# 6   [29 \nMS-1.1-006 \nImplement continuous monito...
# 7   [NOTICE & \nEXPLANATION \nWHY THIS PRINCIPLE I...
# 8   [SAFE AND EFFECTIVE \nSYSTEMS \nWHY THIS PRINC...
# 9   [9 \nand reduced content diversity). Overly ho...
# 10  [10 \nGAI systems can ease the unintentional p...
# 11  [NOTICE & \nEXPLANATION \nWHAT SHOULD BE EXPEC...
# 12  [29 \nMS-1.1-006 \nImplement continuous monito...
# 13  [10 \nGAI systems can ease the unintentional p...
# 14  [DATA PRIVACY \nWHAT SHOULD BE EXPECTED OF AUT...
# 15  [TABLE OF CONTENTS\nFROM PRINCIPLES TO PRACTIC...
# 16  [Algorithmic \nDiscrimination \nProtections \n...
# 17  [DATA PRIVACY \nHOW THESE PRINCIPLES CAN MOVE ...
# 18  [29 \nMS-1.1-006 \nImplement continuous monito...
# 19  [52 \n• \nMonitoring system capabilities and l...
#
#                                                answer  \
# 0   Adversarial role-playing exercises can help id...
# 1   Karen Levy is an Assistant Professor in the De...
# 2   Organizations should establish minimum thresho...
# 3   The significance of algorithmic discrimination...
# 4   Risks can be re-evaluated when adapting Genera...
# 5   Information security for Generative Artificial...
# 6   Label errors can significantly impact the stab...
# 7   Transparency is important in predictive polici...
# 8   Some innovative solutions provided by industry...
# 9   The risks associated with model extraction in ...
# 10  GAI alterations can significantly affect perce...
# 11  Transparency and accessibility in automated sy...
# 12  AI red teams should consider the following fac...
# 13  GAI systems can be used to create targeted dis...
# 14  To protect individuals from government surveil...
# 15  The technical guide protects data privacy in t...
# 16  Organizations can prevent algorithmic discrimi...
# 17  The Privacy Act of 1974 helps individuals corr...
# 18  GAI red-teaming can assess data quality for AI...
# 19  Integrating tools for content provenance analy...
#
#                                          ground_truth  faithfulness  \
# 0   Adversarial role-playing exercises can help id...      1.000000
# 1   Karen Levy is an Assistant Professor in the De...      0.400000
# 2   Organizations should establish minimum thresho...      0.730769
# 3   Algorithmic discrimination protections in heal...      0.923077
# 4   Risks can be re-evaluated when adapting GAI mo...      1.000000
# 5   Information security for GAI models and system...      0.684211
# 6   Label errors in test datasets used to benchmar...      0.904762
# 7   Transparency is important in predictive polici...      0.666667
# 8   Innovative solutions provided by industry to m...      1.000000
# 9   Outputting of training data samples in AI red-...      1.000000
# 10  GAI alterations can significantly impact perce...      1.000000
# 11  Designers, developers, and deployers of automa...      0.958333
# 12  AI red teams should consider domain expertise,...      1.000000
# 13  GAI systems can be used to create targeted dis...      1.000000
# 14  Some of the safeguards needed to protect indiv...      1.000000
# 15  The answer to given question is not present in...      0.769231
# 16  Proactive testing should be performed to ident...      1.000000
# 17  The Privacy Act allows individuals to access t...      1.000000
# 18  GAI red-teaming can assess data quality for AI...      0.875000
# 19  Integrating tools for content provenance analy...      0.692308
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.938997        1.000000               1.00            0.712726
# 1           0.943888        1.000000               0.75            0.997571
# 2           0.849538        1.000000               1.00            0.277228
# 3           1.000000        1.000000               1.00            0.742212
# 4           0.928705        1.000000               1.00            0.900584
# 5           0.911603        1.000000               1.00            0.338197
# 6           0.958014        1.000000               1.00            0.341887
# 7           1.000000        0.666667               1.00            0.997714
# 8           0.973194        1.000000               1.00            0.849891
# 9           1.000000        1.000000               1.00            0.989895
# 10          0.954281        1.000000               1.00            0.821147
# 11          0.998483        1.000000               1.00            0.830805
# 12          0.960951        1.000000               1.00            0.899341
# 13          1.000000        1.000000               1.00            0.638944
# 14          1.000000        1.000000               1.00            0.445403
# 15          1.000000        1.000000               0.00            0.927357
# 16          1.000000        1.000000               1.00            0.529059
# 17          0.926506        1.000000               1.00            0.954776
# 18          1.000000        1.000000               1.00            0.917998
# 19          0.959486        0.666667               1.00            0.762347
